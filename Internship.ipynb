# %%
from transformers import TapexTokenizer, BartForConditionalGeneration
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df=df.drop(['Period'],axis=1)

# %%
df
# Out:
#     Company Name            Category   Sub Cat  Value - Randomized
# 0    Potato Inc.   Revenue By Region  Americas        1.830000e+11
# 1    Potato Inc.   Revenue By Region  Americas        1.710000e+11
# 2    Potato Inc.   Revenue By Region  Americas        8.084000e+10
# 3    Potato Inc.   Revenue By Region  Americas        6.531000e+10
# 4    Potato Inc.   Revenue By Region  Americas        2.350000e+11
# ..           ...                 ...       ...                 ...
# 345  Potato Inc.  Revenue By Product     Other        3.233600e+10
# 346  Potato Inc.  Revenue By Product     Other        4.825000e+10
# 347  Potato Inc.  Revenue By Product     Other        8.089200e+10
# 348  Potato Inc.  Revenue By Product     Other        3.502800e+10
# 349  Potato Inc.  Revenue By Product     Other        2.485200e+10
#
# [350 rows x 4 columns]

# %%
df = df.rename(columns={'Value - Randomized': 'Revenue'})

# %%
df=df.drop(['Company Name','Category'],axis=1)

# %%
df
# Out:
#       Sub Cat       Revenue
# 0    Americas  1.830000e+11
# 1    Americas  1.710000e+11
# 2    Americas  8.084000e+10
# 3    Americas  6.531000e+10
# 4    Americas  2.350000e+11
# ..        ...           ...
# 345     Other  3.233600e+10
# 346     Other  4.825000e+10
# 347     Other  8.089200e+10
# 348     Other  3.502800e+10
# 349     Other  2.485200e+10
#
# [350 rows x 2 columns]

# %%
df = df[df['Sub Cat'].isin(['Japan', 'Smartphones'])]

# %%
df
# Out:
#          Sub Cat       Revenue
# 105        Japan  2.725000e+10
# 106        Japan  1.038000e+10
# 107        Japan  2.009000e+10
# 108        Japan  2.358000e+10
# 109        Japan  2.874000e+10
# ..           ...           ...
# 205  Smartphones  2.030000e+11
# 206  Smartphones  1.280000e+11
# 207  Smartphones  4.600000e+11
# 208  Smartphones  2.050000e+11
# 209  Smartphones  1.590000e+11
#
# [70 rows x 2 columns]

# %%
tokenizer = TapexTokenizer.from_pretrained("microsoft/tapex-large-finetuned-wtq")
model = BartForConditionalGeneration.from_pretrained("microsoft/tapex-large-finetuned-wtq")


table = pd.DataFrame.from_dict(df)

# %%
table['Revenue'] = table['Revenue'].astype(str)

# %%
# tapex accepts uncased input since it is pre-trained on the uncased corpus
query = "How much revenue does Potato Inc. make from Japan?"
encoding = tokenizer(table=table, query=query, return_tensors="pt")

outputs = model.generate(**encoding)

print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# [' 27250000000.0']

# %%
# tapex accepts uncased input since it is pre-trained on the uncased corpus
query = "“How much revenue does Potato Inc. make from selling Smartphones"
encoding = tokenizer(table=table, query=query, return_tensors="pt")

outputs = model.generate(**encoding)

print(tokenizer.batch_decode(outputs, skip_special_tokens=True))
# Out:
# [' 86886000000.0']
